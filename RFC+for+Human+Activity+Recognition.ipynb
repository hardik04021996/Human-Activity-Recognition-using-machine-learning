# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.grid_search import GridSearchCV
# Out:
# /usr/local/lib/python2.7/dist-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# /usr/local/lib/python2.7/dist-packages/sklearn/grid_search.py:42: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)

# %%
xtrain=pd.read_table('/home/hardik/Desktop/UCI HAR Dataset/train/X_train.txt',delim_whitespace=True,header=None)

# %%
xtest=pd.read_table('/home/hardik/Desktop/UCI HAR Dataset/test/X_test.txt',delim_whitespace=True,header=None)

# %%
ytrain=pd.read_table('/home/hardik/Desktop/UCI HAR Dataset/train/y_train.txt',header=None)

# %%
ytest=pd.read_table('/home/hardik/Desktop/UCI HAR Dataset/test/y_test.txt',header=None)

# %%
xtrain.head()
# Out:
#         0         1         2         3         4         5         6    \
# 0  0.288585 -0.020294 -0.132905 -0.995279 -0.983111 -0.913526 -0.995112
# 1  0.278419 -0.016411 -0.123520 -0.998245 -0.975300 -0.960322 -0.998807
# 2  0.279653 -0.019467 -0.113462 -0.995380 -0.967187 -0.978944 -0.996520
# 3  0.279174 -0.026201 -0.123283 -0.996091 -0.983403 -0.990675 -0.997099
# 4  0.276629 -0.016570 -0.115362 -0.998139 -0.980817 -0.990482 -0.998321
#
#         7         8         9      ...          551       552       553  \
# 0 -0.983185 -0.923527 -0.934724    ...    -0.074323 -0.298676 -0.710304
# 1 -0.974914 -0.957686 -0.943068    ...     0.158075 -0.595051 -0.861499
# 2 -0.963668 -0.977469 -0.938692    ...     0.414503 -0.390748 -0.760104
# 3 -0.982750 -0.989302 -0.938692    ...     0.404573 -0.117290 -0.482845
# 4 -0.979672 -0.990441 -0.942469    ...     0.087753 -0.351471 -0.699205
#
#         554       555       556       557       558       559       560
# 0 -0.112754  0.030400 -0.464761 -0.018446 -0.841247  0.179941 -0.058627
# 1  0.053477 -0.007435 -0.732626  0.703511 -0.844788  0.180289 -0.054317
# 2 -0.118559  0.177899  0.100699  0.808529 -0.848933  0.180637 -0.049118
# 3 -0.036788 -0.012892  0.640011 -0.485366 -0.848649  0.181935 -0.047663
# 4  0.123320  0.122542  0.693578 -0.615971 -0.847865  0.185151 -0.043892
#
# [5 rows x 561 columns]

# %%
classifier = RandomForestClassifier()

# %%
parameters = {'n_estimators': [10, 100, 1000], 'max_depth': [3, 6, 9], 'max_features' : ['auto', 'log2']}

# %%
model=GridSearchCV(classifier,parameters,n_jobs=-1,cv=4,scoring='accuracy',verbose=4)
model.fit(xtrain.as_matrix(),ytrain.as_matrix().ravel().T)
# Out:
# Fitting 4 folds for each of 18 candidates, totalling 72 fits
# [CV] max_features=auto, n_estimators=10, max_depth=3 .................
# [CV] max_features=auto, n_estimators=10, max_depth=3 .................
# [CV] max_features=auto, n_estimators=10, max_depth=3 .................
# [CV] max_features=auto, n_estimators=10, max_depth=3 .................
# [CV]  max_features=auto, n_estimators=10, max_depth=3, score=0.839761 -   1.2s
# [CV] max_features=auto, n_estimators=100, max_depth=3 ................
# [CV]  max_features=auto, n_estimators=10, max_depth=3, score=0.844565 -   1.2s
# [CV] max_features=auto, n_estimators=100, max_depth=3 ................
# [CV]  max_features=auto, n_estimators=10, max_depth=3, score=0.803922 -   1.3s
# [CV] max_features=auto, n_estimators=100, max_depth=3 ................
# [CV]  max_features=auto, n_estimators=10, max_depth=3, score=0.887193 -   1.2s
# [CV] max_features=auto, n_estimators=100, max_depth=3 ................
# [CV]  max_features=auto, n_estimators=100, max_depth=3, score=0.881522 -   7.5s
# [CV] max_features=auto, n_estimators=1000, max_depth=3 ...............
# [CV]  max_features=auto, n_estimators=100, max_depth=3, score=0.857686 -   7.6s
# [CV] max_features=auto, n_estimators=1000, max_depth=3 ...............
# [CV]  max_features=auto, n_estimators=100, max_depth=3, score=0.863834 -   7.5s
# [CV] max_features=auto, n_estimators=1000, max_depth=3 ...............
# [CV]  max_features=auto, n_estimators=100, max_depth=3, score=0.901362 -   7.5s
# [CV] max_features=auto, n_estimators=1000, max_depth=3 ...............
# [CV]  max_features=auto, n_estimators=1000, max_depth=3, score=0.845193 - 1.2min
# [CV] max_features=log2, n_estimators=10, max_depth=3 .................
# [CV]  max_features=log2, n_estimators=10, max_depth=3, score=0.764802 -   0.7s
# [CV] max_features=log2, n_estimators=10, max_depth=3 .................
# [CV]  max_features=auto, n_estimators=1000, max_depth=3, score=0.850763 - 1.2min
# [CV] max_features=log2, n_estimators=10, max_depth=3 .................
# [CV]  max_features=log2, n_estimators=10, max_depth=3, score=0.832609 -   0.8s
# [CV] max_features=log2, n_estimators=10, max_depth=3 .................
# [CV]  max_features=log2, n_estimators=10, max_depth=3, score=0.777233 -   0.8s
# [CV]  max_features=auto, n_estimators=1000, max_depth=3, score=0.859783 - 1.2min
# [CV] max_features=log2, n_estimators=100, max_depth=3 ................
# [CV] max_features=log2, n_estimators=100, max_depth=3 ................
# [CV]  max_features=auto, n_estimators=1000, max_depth=3, score=0.923706 - 1.2min
# [CV] max_features=log2, n_estimators=100, max_depth=3 ................
# [CV]  max_features=log2, n_estimators=10, max_depth=3, score=0.862670 -   0.9s
# [CV] max_features=log2, n_estimators=100, max_depth=3 ................
# [CV]  max_features=log2, n_estimators=100, max_depth=3, score=0.824009 -   4.1s
# [CV] max_features=log2, n_estimators=1000, max_depth=3 ...............
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:  1.4min
# [CV]  max_features=log2, n_estimators=100, max_depth=3, score=0.824457 -   4.3s
# [CV] max_features=log2, n_estimators=1000, max_depth=3 ...............
# [CV]  max_features=log2, n_estimators=100, max_depth=3, score=0.793028 -   4.3s
# [CV] max_features=log2, n_estimators=1000, max_depth=3 ...............
# [CV]  max_features=log2, n_estimators=100, max_depth=3, score=0.892643 -   4.4s
# [CV] max_features=log2, n_estimators=1000, max_depth=3 ...............
# [CV]  max_features=log2, n_estimators=1000, max_depth=3, score=0.812059 -  34.8s
# [CV] max_features=auto, n_estimators=10, max_depth=6 .................
# [CV]  max_features=log2, n_estimators=1000, max_depth=3, score=0.788126 -  34.7s
# [CV] max_features=auto, n_estimators=10, max_depth=6 .................
# [CV]  max_features=log2, n_estimators=1000, max_depth=3, score=0.895368 -  34.4s
# [CV] max_features=auto, n_estimators=10, max_depth=6 .................
# [CV]  max_features=log2, n_estimators=1000, max_depth=3, score=0.834239 -  35.6s
# [CV] max_features=auto, n_estimators=10, max_depth=6 .................
# [CV]  max_features=auto, n_estimators=10, max_depth=6, score=0.891907 -   1.8s
# [CV] max_features=auto, n_estimators=100, max_depth=6 ................
# [CV]  max_features=auto, n_estimators=10, max_depth=6, score=0.875000 -   1.7s
# [CV] max_features=auto, n_estimators=100, max_depth=6 ................
# [CV]  max_features=auto, n_estimators=10, max_depth=6, score=0.863290 -   1.8s
# [CV] max_features=auto, n_estimators=100, max_depth=6 ................
# [CV]  max_features=auto, n_estimators=10, max_depth=6, score=0.929155 -   1.6s
# [CV] max_features=auto, n_estimators=100, max_depth=6 ................
# [CV]  max_features=auto, n_estimators=100, max_depth=6, score=0.907659 -  12.3s
# [CV] max_features=auto, n_estimators=1000, max_depth=6 ...............
# [CV]  max_features=auto, n_estimators=100, max_depth=6, score=0.902174 -  12.3s
# [CV] max_features=auto, n_estimators=1000, max_depth=6 ...............
# [CV]  max_features=auto, n_estimators=100, max_depth=6, score=0.946049 -  12.2s
# [CV] max_features=auto, n_estimators=1000, max_depth=6 ...............
# [CV]  max_features=auto, n_estimators=100, max_depth=6, score=0.880174 -  12.4s
# [CV] max_features=auto, n_estimators=1000, max_depth=6 ...............
# [CV]  max_features=auto, n_estimators=1000, max_depth=6, score=0.906573 - 2.0min
# [CV] max_features=log2, n_estimators=10, max_depth=6 .................
# [CV]  max_features=log2, n_estimators=10, max_depth=6, score=0.859316 -   0.9s
# [CV] max_features=log2, n_estimators=10, max_depth=6 .................
# [CV]  max_features=auto, n_estimators=1000, max_depth=6, score=0.895652 - 2.1min
# [CV] max_features=log2, n_estimators=10, max_depth=6 .................
# [CV]  max_features=log2, n_estimators=10, max_depth=6, score=0.854891 -   1.1s
# [CV] max_features=log2, n_estimators=10, max_depth=6 .................
# [CV]  max_features=log2, n_estimators=10, max_depth=6, score=0.843137 -   1.2s
# [CV] max_features=log2, n_estimators=100, max_depth=6 ................
# [CV]  max_features=auto, n_estimators=1000, max_depth=6, score=0.898693 - 2.1min
# [CV] max_features=log2, n_estimators=100, max_depth=6 ................
# [CV]  max_features=log2, n_estimators=10, max_depth=6, score=0.937875 -   1.1s
# [CV] max_features=log2, n_estimators=100, max_depth=6 ................
# [CV]  max_features=auto, n_estimators=1000, max_depth=6, score=0.940599 - 2.1min
# [CV] max_features=log2, n_estimators=100, max_depth=6 ................
# [CV]  max_features=log2, n_estimators=100, max_depth=6, score=0.889734 -   6.3s
# [CV] max_features=log2, n_estimators=1000, max_depth=6 ...............
# [CV]  max_features=log2, n_estimators=100, max_depth=6, score=0.903804 -   6.1s
# [CV] max_features=log2, n_estimators=1000, max_depth=6 ...............
# [CV]  max_features=log2, n_estimators=100, max_depth=6, score=0.876906 -   6.4s
# [CV] max_features=log2, n_estimators=1000, max_depth=6 ...............
# [CV]  max_features=log2, n_estimators=100, max_depth=6, score=0.953134 -   6.3s
# [CV] max_features=log2, n_estimators=1000, max_depth=6 ...............
# [CV]  max_features=log2, n_estimators=1000, max_depth=6, score=0.873638 - 1.0min
# [CV] max_features=auto, n_estimators=10, max_depth=9 .................
# [CV]  max_features=log2, n_estimators=1000, max_depth=6, score=0.955313 - 1.1min
# [CV] max_features=auto, n_estimators=10, max_depth=9 .................
# [CV]  max_features=log2, n_estimators=1000, max_depth=6, score=0.890277 - 1.1min
# [CV] max_features=auto, n_estimators=10, max_depth=9 .................
# [CV]  max_features=log2, n_estimators=1000, max_depth=6, score=0.901087 - 1.1min
# [CV] max_features=auto, n_estimators=10, max_depth=9 .................
# [CV]  max_features=auto, n_estimators=10, max_depth=9, score=0.906029 -   2.5s
# [CV] max_features=auto, n_estimators=100, max_depth=9 ................
# [CV]  max_features=auto, n_estimators=10, max_depth=9, score=0.880978 -   2.2s
# [CV] max_features=auto, n_estimators=100, max_depth=9 ................
# [CV]  max_features=auto, n_estimators=10, max_depth=9, score=0.862745 -   2.1s
# [CV] max_features=auto, n_estimators=100, max_depth=9 ................
# [CV]  max_features=auto, n_estimators=10, max_depth=9, score=0.946594 -   2.1s
# [CV] max_features=auto, n_estimators=100, max_depth=9 ................
# [CV]  max_features=auto, n_estimators=100, max_depth=9, score=0.917436 -  17.1s
# [CV] max_features=auto, n_estimators=1000, max_depth=9 ...............
# [CV]  max_features=auto, n_estimators=100, max_depth=9, score=0.892391 -  17.3s
# [CV] max_features=auto, n_estimators=1000, max_depth=9 ...............
# [CV]  max_features=auto, n_estimators=100, max_depth=9, score=0.950954 -  17.6s
# [CV] max_features=auto, n_estimators=1000, max_depth=9 ...............
# [CV]  max_features=auto, n_estimators=100, max_depth=9, score=0.906318 -  17.9s
# [CV] max_features=auto, n_estimators=1000, max_depth=9 ...............
# [CV]  max_features=auto, n_estimators=1000, max_depth=9, score=0.920695 - 2.9min
# [CV] max_features=log2, n_estimators=10, max_depth=9 .................
# [CV]  max_features=auto, n_estimators=1000, max_depth=9, score=0.889130 - 2.9min
# [CV] max_features=log2, n_estimators=10, max_depth=9 .................
# [CV]  max_features=log2, n_estimators=10, max_depth=9, score=0.897882 -   1.5s
# [CV] max_features=log2, n_estimators=10, max_depth=9 .................
# [CV]  max_features=auto, n_estimators=1000, max_depth=9, score=0.891612 - 2.9min
# [CV] max_features=log2, n_estimators=10, max_depth=9 .................
# [CV]  max_features=log2, n_estimators=10, max_depth=9, score=0.882609 -   1.7s
# [CV] max_features=log2, n_estimators=100, max_depth=9 ................
# [CV]  max_features=log2, n_estimators=10, max_depth=9, score=0.884532 -   1.4s
# [CV] max_features=log2, n_estimators=100, max_depth=9 ................
# [CV]  max_features=log2, n_estimators=10, max_depth=9, score=0.937330 -   1.5s
# [CV] max_features=log2, n_estimators=100, max_depth=9 ................
# [CV]  max_features=auto, n_estimators=1000, max_depth=9, score=0.952589 - 3.0min
# [CV] max_features=log2, n_estimators=100, max_depth=9 ................
# [CV]  max_features=log2, n_estimators=100, max_depth=9, score=0.911461 -   9.2s
# [CV] max_features=log2, n_estimators=1000, max_depth=9 ...............
# [CV]  max_features=log2, n_estimators=100, max_depth=9, score=0.907609 -   9.8s
# [CV] max_features=log2, n_estimators=1000, max_depth=9 ...............
# [CV]  max_features=log2, n_estimators=100, max_depth=9, score=0.887800 -   9.6s
# [CV] max_features=log2, n_estimators=1000, max_depth=9 ...............
# [CV]  max_features=log2, n_estimators=100, max_depth=9, score=0.968392 -   9.6s
# [CV] max_features=log2, n_estimators=1000, max_depth=9 ...............
# [CV]  max_features=log2, n_estimators=1000, max_depth=9, score=0.910326 - 1.3min
# [CV]  max_features=log2, n_estimators=1000, max_depth=9, score=0.912004 - 1.4min
# [CV]  max_features=log2, n_estimators=1000, max_depth=9, score=0.903050 - 1.4min
# [CV]  max_features=log2, n_estimators=1000, max_depth=9, score=0.968937 - 1.3min
# [Parallel(n_jobs=-1)]: Done  72 out of  72 | elapsed: 10.3min finished
# GridSearchCV(cv=4, error_score='raise',
#        estimator=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False),
#        fit_params={}, iid=True, n_jobs=-1,
#        param_grid={'n_estimators': [10, 100, 1000], 'max_features': ['auto', 'log2'], 'max_depth': [3, 6, 9]},
#        pre_dispatch='2*n_jobs', refit=True, scoring='accuracy', verbose=4)

# %%
from sklearn.metrics import accuracy_score
ypred=model.predict(xtest)
accuracy=accuracy_score(ytest,ypred)

# %%
print 'Best Parameters: '+ str(model.best_params_)
print 'Accuracy Score: '+ str(accuracy*100) + ' %'
# Out:
# Best Parameters: {'max_features': 'log2', 'n_estimators': 1000, 'max_depth': 9}
# Accuracy Score: 92.8401764506 %
